# %% [markdown]
# ## Ejemplo uso yfinance
#
# Sacado de X, [Python Coding](https://twitter.com/clcoding)
#
# Instalación paquetes:
# ```
# pip install yfinance
# pip install matplotlib
# ```
#
# * Ejemplo 1 - Descargar historial de un activo
# * Ejemplo 2 - Imformación en tiempo Real  (no funciona)
# * Ejemplo 3 - Descarga Multiple de datos de activos
# * Ejemplo 4 - Análisis de datos financieros
# * Ejemplo 5 - Splits y Dividendos

# %%
#   Ejemplo 1 - Descargar historial de un activo

import yfinance as yf


#   Descargar el historial de Apple (AAPL) desde el 1 enero 2024 al 8 de marzo 2024
aapl = yf.download('AAPL', start='2024-01-01', end='2024-03-09')

#   Imprimimos los primeros registros del dataframe
print(aapl.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412  \
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
#
#               Volume
# Date
# 2024-01-02  82488700
# 2024-01-03  58414500
# 2024-01-04  71983600
# 2024-01-05  62303300
# 2024-01-08  59144500

# %%
#   Ejemplo 2 - Información en tiempo real

import yfinance as yf

aapl_quote = yf.Ticker('AAPL').info

print(aapl_quote)

# %%
#   Ejemplo 3 - Descarga Multiple de datos de activos

import yfinance as yf

activos = ['AAPL', 'MSFT']
data = yf.download(activos, start='2024-01-01', end='2024-03-09')

print(data.head())
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                   Close                    High
#                   AAPL        MSFT        AAPL        MSFT        AAPL
# Date
# 2024-01-02  185.403412  370.185425  185.639999  370.869995  188.440002  \
# 2024-01-03  184.015198  369.915924  184.250000  370.600006  185.880005
# 2024-01-04  181.678177  367.260834  181.910004  367.940002  183.089996
# 2024-01-05  180.949097  367.071198  181.179993  367.750000  182.759995
# 2024-01-08  185.323517  373.998383  185.559998  374.690002  185.600006
#
#                                Low                    Open
#                   MSFT        AAPL        MSFT        AAPL        MSFT
# Date
# 2024-01-02  375.899994  183.889999  366.769989  187.149994  373.859985  \
# 2024-01-03  373.260010  183.429993  368.510010  184.220001  369.010010
# 2024-01-04  373.100006  180.880005  367.170013  182.149994  370.670013
# 2024-01-05  372.059998  180.169998  366.500000  181.990005  368.970001
# 2024-01-08  375.200012  181.500000  369.010010  182.089996  369.299988
#
#               Volume
#                 AAPL      MSFT
# Date
# 2024-01-02  82488700  25258600
# 2024-01-03  58414500  23083500
# 2024-01-04  71983600  20901500
# 2024-01-05  62303300  20987000
# 2024-01-08  59144500  23134000

# %%
#   Ejemplo 4 - Análisis de datos financieros

import yfinance as yf
import matplotlib.pyplot as plt

#   Descargamos el historial de datos de Microsot
msft = yf.download('MSFT', start='2024-01-01', end='2024-03-09')

#   Representamos los precios de cierre
plt.figure(figsize=(10, 6))
msft['Close'].plot(title='Microsoft precios de cierre')
plt.xlabel('Fecha')
plt.ylabel('Precios de cierre')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#   Ejemplo 5 - Splits y Dividendos

import yfinance as yf

aapl_dividendos = yf.Ticker('AAPL').dividends
aapl_splits = yf.Ticker('AAPL').splits

print('Dividendos\n', aapl_dividendos)
print("\nSplits\n", aapl_splits)
# Out:
# Dividendos
#  Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# 2023-08-11 00:00:00-04:00    0.240000
# 2023-11-10 00:00:00-05:00    0.240000
# 2024-02-09 00:00:00-05:00    0.240000
# Name: Dividends, Length: 82, dtype: float64
#
# Splits
#  Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64
