# %% [markdown]
# ## Ejemplo uso yfinance
#
# Sacado de X, [Python Coding](https://twitter.com/clcoding)
#
# Instalación paquetes:
# ```
# pip install yfinance
# pip install matplotlib
# ```
#
# * Ejemplo 1 - Descargar historial de un activo
# * Ejemplo 2 - Imformación en tiempo Real  (no funciona)
# * Ejemplo 3 - Descarga Multiple de datos de activos
# * Ejemplo 4 - Representación gráfica para Análisis de datos financieros
# * Ejemplo 5 - Splits y Dividendos

# %%
#   Ejemplo 1 - Descargar historial de un activo

import yfinance as yf

#   Descargar el historial de Apple (AAPL) desde el 1 enero 2024 al 8 de marzo 2024
# aapl = yf.download('AAPL', start='2024-01-01', end='2024-03-09')
aapl = yf.download('NVDA')

#   Imprimimos los primeros registros del dataframe
# print(aapl.head())
print(aapl)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close
# Date
# 1999-01-22     0.437500     0.488281     0.388021     0.410156     0.376237  \
# 1999-01-25     0.442708     0.458333     0.410156     0.453125     0.415653
# 1999-01-26     0.458333     0.467448     0.411458     0.417969     0.383404
# 1999-01-27     0.419271     0.429688     0.395833     0.416667     0.382210
# 1999-01-28     0.416667     0.419271     0.412760     0.415365     0.381015
# ...                 ...          ...          ...          ...          ...
# 2024-06-03  1136.209961  1150.000000  1120.030029  1150.000000  1150.000000
# 2024-06-04  1157.160034  1166.000000  1140.449951  1164.369995  1164.369995
# 2024-06-05  1183.709961  1224.489990  1174.680054  1224.400024  1224.400024
# 2024-06-06  1240.479980  1255.869995  1183.199951  1209.979980  1209.979980
# ...

# %%
#   Ejemplo 2 - Información en tiempo real

import yfinance as yf

aapl_quote = yf.Ticker('NVDA').info

#  devuelve error => 
#   HTTPError: 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance

# %%
#   Ejemplo 3 - Descarga Multiple de datos de activos

import yfinance as yf

activos = ['NVDA', 'AAPL', 'MSFT']

# data = yf.download(activos, start='2024-01-01', end='2024-03-09')
data = yf.download(activos)

print(data.head())
# Out:
# [*********************100%***********************]  3 of 3 completed
#            Adj Close               Close                High
#                 AAPL MSFT NVDA      AAPL MSFT NVDA      AAPL MSFT NVDA
# Date
# 1980-12-12  0.099058  NaN  NaN  0.128348  NaN  NaN  0.128906  NaN  NaN  \
# 1980-12-15  0.093890  NaN  NaN  0.121652  NaN  NaN  0.122210  NaN  NaN
# 1980-12-16  0.086999  NaN  NaN  0.112723  NaN  NaN  0.113281  NaN  NaN
# 1980-12-17  0.089152  NaN  NaN  0.115513  NaN  NaN  0.116071  NaN  NaN
# 1980-12-18  0.091737  NaN  NaN  0.118862  NaN  NaN  0.119420  NaN  NaN
#
#                  Low                Open               Volume
#                 AAPL MSFT NVDA      AAPL MSFT NVDA       AAPL MSFT NVDA
# Date
# 1980-12-12  0.128348  NaN  NaN  0.128348  NaN  NaN  469033600  NaN  NaN
# 1980-12-15  0.121652  NaN  NaN  0.122210  NaN  NaN  175884800  NaN  NaN
# 1980-12-16  0.112723  NaN  NaN  0.113281  NaN  NaN  105728000  NaN  NaN
# ...

# %%
#   Ejemplo 4 - Análisis de datos financieros

import yfinance as yf
import matplotlib.pyplot as plt

#   Descargamos el historial de datos de Microsot
activo = yf.download('NVDA')

#   Representamos los precios de cierre
plt.figure(figsize=(10, 6))
activo['Close'].plot(title='NVIDIA precios de cierre')
plt.xlabel('Fecha')
plt.ylabel('Precios de cierre')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#   Ejemplo 5 - Splits y Dividendos

import yfinance as yf

aapl_dividendos = yf.Ticker('AAPL').dividends
aapl_splits = yf.Ticker('AAPL').splits

print('Dividendos\n', aapl_dividendos)
print("\nSplits\n", aapl_splits)
# Out:
# Dividendos
#  Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# 2023-08-11 00:00:00-04:00    0.240000
# 2023-11-10 00:00:00-05:00    0.240000
# 2024-02-09 00:00:00-05:00    0.240000
# Name: Dividends, Length: 82, dtype: float64
#
# Splits
#  Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %% [markdown]
# ### Análisis valor Caixabank
#
# En la lectura del gráfico de Caixabank desde el 2007 tiene bajadas y subidas máximas.
#
# * Se mueve desde **4,23** nov 2007    para bajar **1,79** en feb. 2009
# * Sube a **4,23** en feb 2011         y vuelve a bajar a los **1,68** en mayo 2012
# * sube a **4,55** en sept 2014        para volver a bajar a los **1,94** en junio 2016
# * sube a **4,18** en junio 2016       y baja a los **1,56** en octubre 2020
#
# ahora alcanza los **5,07**          ESTA A PUNTO DE BAJAR???
#
# - Analizar los splits que tiene y que valor tenía la acción antes y después

# %%
import yfinance as yf

valor = 'CABK.MC'
valor = 'NVDA'

dividendos = yf.Ticker(valor).dividends

print('Dividendos\n', dividendos)
# Out:
# Dividendos
#  Date
# 2012-11-20 00:00:00-05:00    0.01875
# 2013-02-26 00:00:00-05:00    0.01875
# 2013-05-21 00:00:00-04:00    0.01875
# 2013-08-20 00:00:00-04:00    0.01875
# 2013-11-19 00:00:00-05:00    0.02125
# 2014-02-25 00:00:00-05:00    0.02125
# 2014-05-20 00:00:00-04:00    0.02125
# 2014-08-19 00:00:00-04:00    0.02125
# 2014-11-19 00:00:00-05:00    0.02125
# 2015-02-24 00:00:00-05:00    0.02125
# 2015-05-19 00:00:00-04:00    0.02450
# 2015-08-18 00:00:00-04:00    0.02450
# 2015-11-18 00:00:00-05:00    0.02875
# 2016-02-29 00:00:00-05:00    0.02875
# 2016-05-24 00:00:00-04:00    0.02875
# 2016-08-23 00:00:00-04:00    0.02875
# 2016-11-23 00:00:00-05:00    0.03500
# 2017-02-22 00:00:00-05:00    0.03500
# 2017-05-19 00:00:00-04:00    0.03500
# 2017-08-22 00:00:00-04:00    0.03500
# 2017-11-22 00:00:00-05:00    0.03750
# 2018-02-22 00:00:00-05:00    0.03750
# 2018-05-23 00:00:00-04:00    0.03750
# 2018-08-29 00:00:00-04:00    0.03750
# 2018-11-29 00:00:00-05:00    0.04000
# ...

# %%
splits = yf.Ticker(valor).splits

print("\nSplits\n", splits)
# Out:
# Splits
#  Date
# 2000-06-27 00:00:00-04:00    2.0
# 2001-09-10 00:00:00-04:00    2.0
# 2006-04-07 00:00:00-04:00    2.0
# 2007-09-11 00:00:00-04:00    1.5
# 2021-07-20 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64
