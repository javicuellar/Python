# %% [markdown]
# # Ejemplos de uso de librería yfinance
#
# https://pypi.org/project/yfinance/
#
# Blog - https://aroussi.com/post/python-yahoo-finance

# %%
import yfinance as yf

# %% [markdown]
# ### Ejemplo 1 - Lectura ticker activo, obtener información, histórico, GRAFICAR, etc.

# %%
#  Lectura Ticker - Acción, fondo, ...
bbva = yf.Ticker("BBVA.MC")

# %%
#  Obtener información del activo
bbvaInfo = bbva.info            # recuperamos diccionario
print(f"País.- {bbvaInfo['country']}")
print(f"Sector.- {bbvaInfo['sector']}")
print(f"trailingAnnualDividendYield.- {bbvaInfo['trailingAnnualDividendYield']*100:.3}%")

print("\nInformación acción BBVA\n", bbvaInfo)
# Out:
# País.- Spain
# Sector.- Financial Services
# trailingAnnualDividendYield.- 6.27%
#
# Información acción BBVA
# ...

# %%
#  Mostrar eventos del activo (dividends, splits)
print("\nEventos: Dividendos y Splits\n", bbva.actions)
# Out:
# Eventos: Dividendos y Splits
#                             Dividends  Stock Splits
# Date
# 2008-01-10 00:00:00+01:00   0.146033           0.0
# 2008-04-10 00:00:00+02:00   0.266126           0.0
# 2008-07-10 00:00:00+02:00   0.160444           0.0
# 2008-10-10 00:00:00+02:00   0.160444           0.0
# 2009-01-12 00:00:00+01:00   0.160444           0.0
# 2009-07-10 00:00:00+02:00   0.086467           0.0
# 2009-10-12 00:00:00+02:00   0.086467           0.0
# 2009-12-28 00:00:00+01:00   0.086467           0.0
# 2010-04-12 00:00:00+02:00   0.144112           0.0
# 2010-07-12 00:00:00+02:00   0.086467           0.0
# 2010-10-11 00:00:00+02:00   0.086467           0.0
# 2011-01-10 00:00:00+01:00   0.090000           0.0
# 2011-04-01 00:00:00+02:00   0.149000           0.0
# 2011-07-08 00:00:00+02:00   0.100000           0.0
# 2011-09-30 00:00:00+02:00   0.100000           0.0
# 2012-01-10 00:00:00+01:00   0.100000           0.0
# 2012-04-16 00:00:00+02:00   0.118000           0.0
# ...

# %%
#  Obtener información histórica: 5d (días), 5y (años),  ytd y max
hist = bbva.history(period="15y")
print("\n ---   histórico  ---\n", hist.head())
# Out:
#  ---   histórico  ---
#                                 Open      High       Low     Close    Volume  \
# Date
# 2007-11-26 00:00:00+01:00  7.394280  7.434638  7.286663  7.300115  30359023
# 2007-11-27 00:00:00+01:00  7.300117  7.349442  7.237339  7.282180  32848250
# 2007-11-28 00:00:00+01:00  7.282179  7.524321  7.259759  7.448091  44571606
# 2007-11-29 00:00:00+01:00  7.448089  7.578128  7.448089  7.560192  46339815
# 2007-11-30 00:00:00+01:00  7.560193  7.654359  7.519835  7.627454  45831080
#
#                            Dividends  Stock Splits
# Date
# 2007-11-26 00:00:00+01:00        0.0             0
# 2007-11-27 00:00:00+01:00        0.0             0
# 2007-11-28 00:00:00+01:00        0.0             0
# 2007-11-29 00:00:00+01:00        0.0             0
# 2007-11-30 00:00:00+01:00        0.0             0

# %%
#  Representar gráficamente con matplotlib
import matplotlib.pyplot as plt

hist.reset_index(inplace=True)
hist.plot(x="Date", y="Close")
plt.grid()
plt.show()

# %%
#  Graficamos los dividendos de BBVA
hist.plot(x='Date', y='Dividends')
plt.show()

# %%
print("Recomendaciones: ", bbva.recommendations)
print("ISIN: ", bbva.isin)
# Out:
# Recomendaciones:  None
# ISIN:  COB13PA00019

# %% [markdown]
# ### yFinance -> opciones

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")

# show actions (dividends, splits)
msft.actions

# show dividends
msft.dividends

# show splits
msft.splits

# show financials
msft.financials
msft.quarterly_financials

# show major holders
msft.major_holders

# show institutional holders
msft.institutional_holders

# show balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet

# show cashflow
msft.cashflow
msft.quarterly_cashflow

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations

# show next event (earnings, etc)
msft.calendar

# show all earnings dates
msft.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news

# get option chain for specific expiration
# no funciona
# #  opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts

# %% [markdown]
# ### Lectura de varios Ticker con hilos (Thread)

# %%
import yfinance as yf

data = yf.download("SPY AAPL", start="2022-01-01", end="2022-11-30")

print(data)
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                   Close                    High
#                   AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2022-01-03  180.434311  468.296387  182.009995  477.709991  182.880005  \
# 2022-01-04  178.144287  468.139587  179.699997  477.549988  182.940002
# 2022-01-05  173.405670  459.150299  174.919998  468.380005  180.169998
# 2022-01-06  170.510956  458.718903  172.000000  467.940002  175.300003
# 2022-01-07  170.679504  456.905396  172.169998  466.089996  174.139999
# ...                ...         ...         ...         ...         ...
# 2022-11-22  149.743912  396.558594  150.179993  399.899994  150.419998
# 2022-11-23  150.631348  399.057526  151.070007  402.420013  151.830002
# 2022-11-25  147.679932  398.968262  148.110001  402.329987  148.880005
# 2022-11-28  143.801239  392.601898  144.220001  395.910004  146.639999
# ...
